# %% [markdown]
# ## Functions

# %% [markdown]
# Functions in Python group resuable code into a  block that can be executed by calling and make programs modular and readable . There are Many Inbuilt Functions in Python like print(), input() etc:
#
# We can create our own functions . To make a function in python we have to use **def keyword and then name the funciton, after this you have to call the function using name and parenthesis**

# %% [markdown]
# **FUNCTION PARAMETRS AND ARGUMENTS**
#
# Parameters : Variable Listed inside function definition
# Arguments : Value passed to the function
#
# **Types of Argument :**
#     3 types of argument are there
#         1. **Positional Argument**
#         2. **Default Argument**
#         3. **Keyword Argument**

# %%
## Creata a function

def hello():
    print("Hello World")
hello()
hello()
hello()
# Out:
# Hello World
# Hello World
# Hello World

# %%
## Parameters Function

def hello(name):  ## DEFAULT ARGUMENT
    print(f"hello , {name}")

hello(name="Bond")
hello(name="James")
hello("Peter")
# Out:
# hello , Bond
# hello , James
# hello , Peter

# %%
def hello(name="Python"): ## KEYWORD ARGUMENT
    print(f"hello , {name}")
hello()
hello("James")
# Out:
# hello , Python
# hello , James

# %%
def sum (a, b):
    print(f"Sum of your number is : {a + b}")

sum (4 ,5)
sum (12 , 13)
sum (15 , 12)
# Out:
# Sum of your number is : 9
# Sum of your number is : 25
# Sum of your number is : 27

# %%
def palindrome(st):
    rev = ""
    for i in range(len(st)-1,-1,-1):
        rev = rev + st[i]
    if rev == st:
        print("palindrome")
    else:
        print("not a palindrome")


palindrome("Hello")
palindrome("SOS")
# Out:
# not a palindrome
# palindrome
